# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# !pip install ydata-profiling
# Out:
# Requirement already satisfied: ydata-profiling in c:\users\user\anaconda3\lib\site-packages (4.18.1)
# Requirement already satisfied: scipy<1.17,>=1.8 in c:\users\user\anaconda3\lib\site-packages (from ydata-profiling) (1.16.3)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.5 in c:\users\user\anaconda3\lib\site-packages (from ydata-profiling) (2.3.3)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in c:\users\user\anaconda3\lib\site-packages (from ydata-profiling) (3.10.0)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\user\anaconda3\lib\site-packages (from ydata-profiling) (2.12.4)
# Requirement already satisfied: PyYAML<6.1,>=6.0.3 in c:\users\user\anaconda3\lib\site-packages (from ydata-profiling) (6.0.3)
# Requirement already satisfied: jinja2<3.2,>=3.1.6 in c:\users\user\anaconda3\lib\site-packages (from ydata-profiling) (3.1.6)
# Requirement already satisfied: visions<0.8.2,>=0.7.5 in c:\users\user\anaconda3\lib\site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (0.8.1)
# Requirement already satisfied: numpy<2.4,>=1.22 in c:\users\user\anaconda3\lib\site-packages (from ydata-profiling) (2.3.5)
# Requirement already satisfied: minify-html>=0.15.0 in c:\users\user\anaconda3\lib\site-packages (from ydata-profiling) (0.18.1)
# Requirement already satisfied: filetype>=1.0.0 in c:\users\user\anaconda3\lib\site-packages (from ydata-profiling) (1.2.0)
# Requirement already satisfied: phik<0.13,>=0.12.5 in c:\users\user\anaconda3\lib\site-packages (from ydata-profiling) (0.12.5)
# Requirement already satisfied: requests<3,>=2.32.0 in c:\users\user\anaconda3\lib\site-packages (from ydata-profiling) (2.32.5)
# Requirement already satisfied: tqdm<5,>=4.66.3 in c:\users\user\anaconda3\lib\site-packages (from ydata-profiling) (4.67.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in c:\users\user\anaconda3\lib\site-packages (from ydata-profiling) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in c:\users\user\anaconda3\lib\site-packages (from ydata-profiling) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in c:\users\user\anaconda3\lib\site-packages (from ydata-profiling) (0.14.5)
# Requirement already satisfied: typeguard<5,>=4 in c:\users\user\anaconda3\lib\site-packages (from ydata-profiling) (4.5.1)
# Requirement already satisfied: imagehash==4.3.2 in c:\users\user\anaconda3\lib\site-packages (from ydata-profiling) (4.3.2)
# Requirement already satisfied: wordcloud>=1.9.4 in c:\users\user\anaconda3\lib\site-packages (from ydata-profiling) (1.9.6)
# Requirement already satisfied: dacite<2,>=1.9 in c:\users\user\anaconda3\lib\site-packages (from ydata-profiling) (1.9.2)
# Requirement already satisfied: numba<0.63,>=0.60 in c:\users\user\anaconda3\lib\site-packages (from ydata-profiling) (0.62.1)
# Requirement already satisfied: PyWavelets in c:\users\user\anaconda3\lib\site-packages (from imagehash==4.3.2->ydata-profiling) (1.9.0)
# Requirement already satisfied: pillow in c:\users\user\anaconda3\lib\site-packages (from imagehash==4.3.2->ydata-profiling) (12.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\lib\site-packages (from jinja2<3.2,>=3.1.6->ydata-profiling) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in c:\users\user\anaconda3\lib\site-packages (from numba<0.63,>=0.60->ydata-profiling) (0.45.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\anaconda3\lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2025.2)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\user\anaconda3\lib\site-packages (from phik<0.13,>=0.12.5->ydata-profiling) (1.5.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\user\anaconda3\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\user\anaconda3\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\user\anaconda3\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\user\anaconda3\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (2026.1.4)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\user\anaconda3\lib\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (1.0.1)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from tqdm<5,>=4.66.3->ydata-profiling) (0.4.6)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\user\anaconda3\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (25.4.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\user\anaconda3\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (3.5)
# Requirement already satisfied: puremagic in c:\users\user\anaconda3\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (2.1.1)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling) (1.17.0)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\user\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\user\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\user\anaconda3\Lib\site-packages)

# %%
import ydata_profiling as pp

# %%
# data fething

df= pd.read_csv('../datasets/smartwatches.csv')
df.head()
# Out:
#    Unnamed: 0       Brand  Current Price  Original Price  Discount Percentage  \
# 0           0       noise        82990.0         89900.0             7.686318
# 1           1  fire-boltt         3799.0         16999.0            77.651627
# 2           2        boat         1999.0          7990.0            74.981227
# 3           3  fire-boltt         1799.0         19999.0            91.004550
# 4           4       noise         1599.0          4999.0            68.013603
#
#    Rating  Number OF Ratings                              Model Name  \
# 0     4.0               65.0   Wrb-sw-colorfitpro4alpha-std-rgld_pnk
# 1     4.3            20788.0                                  BSW046
# 2     3.8            21724.0                               Wave Call
# 3     4.3            13244.0                                  BSW053
# 4     4.1            13901.0  Wrb-sw-colorfitpulsegobuzz-std-blk_blk
#
#   Dial Shape Strap Color Strap Material Touchscreen  Battery Life (Days)  \
# 0        NaN         NaN            NaN         NaN                  8.0
# 1        NaN         NaN        Silicon         Yes                  3.5
# 2        NaN         NaN        Silicon         Yes                  8.0
# 3        NaN         NaN        Silicon         Yes                  3.5
# 4        NaN         NaN          Other         Yes                  8.0
#
#   Bluetooth Display Size     Weight
# 0       Yes          NaN  35 - 50 g
# 1       Yes   1.8 inches  50 - 75 g
# 2       Yes   1.7 inches  35 - 50 g
# 3       Yes   1.8 inches      75g +
# 4       Yes   1.7 inches  35 - 50 g

# %%
df.shape
# Out:
# (450, 16)

# %%
#cehck duplicates

df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
#separate train and test data
train_df=df.sample(frac=0.8)
test_df=df.drop(train_df.index)

# %%
 train_df.reset_index()
# Out:
#      index       Brand  Current Price  Original Price  Discount Percentage  \
# 0      265      garmin        33490.0         36990.0             9.462017
# 1      302      fossil         9995.0         17995.0            44.456794
# 2      297      fossil        17995.0             NaN                  NaN
# 3      285      huawei        14990.0         19990.0            25.012506
# 4      440  fire-boltt         5599.0          9999.0            44.004400
# ..     ...         ...            ...             ...                  ...
# 355    319        dizo         1799.0          4999.0            64.012803
# 356    239     amazfit         4499.0          5999.0            25.004167
# 357    429  fire-boltt         3499.0          9999.0            65.006501
# 358    131       apple        49666.0         50900.0             2.424361
# 359     43  crossbeats         2999.0          9999.0            70.007001
#
#      Rating  Number OF Ratings  \
# 0       4.6                5.0
# 1       4.0             1532.0
# 2       3.9               46.0
# 3       4.7                NaN
# 4       2.5                NaN
# ..      ...                ...
# 355     4.2            34953.0
# 356     4.1              333.0
# 357     3.7                NaN
# 358     4.5             1519.0
# 359     4.3              674.0
#
#                                             Model Name Dial Shape Strap Color  \
# 0    Instinct 2, Battery Upto 28 days, Tracback Rou...     Circle       Black
# 1                                             Sport 43     Circle        Blue
# 2                                     Sport Smartwatch     Circle  Multicolor
# 3                                   Watch GT 2 (42 mm)     Circle       Black
# 4                                               bsw017     Square        Blue
# ..                                                 ...        ...         ...
# 355  Watch D 1.8 inch Dynamic display with 550nits ...  Rectangle       Black
# 356  Bip 3 Pro with 1.69 inch Large Color Display B...     Square       Beige
# 357                                          beast pro     Square        Blue
# 358  Watch Series7 (GPS + Cellular, 41mm)Blue Alumi...  Rectangle        Blue
# 359                                               Grit        NaN         NaN
#
#       Strap Material Touchscreen  Battery Life (Days) Bluetooth Display Size  \
# 0            Silicon          No                 17.5       Yes   0.9 inches
# 1            Silicon         Yes                  3.5       Yes   1.2 inches
# 2            Silicon         Yes                 17.5       Yes   1.2 inches
# 3    Fluoroelastomer         Yes                 22.0       Yes   1.7 inches
# 4            Silicon         Yes                 22.0       Yes   1.3 inches
# ..               ...         ...                  ...       ...          ...
# 355          Silicon         Yes                  8.0       Yes   1.8 inches
# 356          Silicon         Yes                  8.0       Yes   1.7 inches
# 357           Rubber         Yes                  8.0       Yes   0.1 inches
# 358        Aluminium         Yes                 22.0       Yes   1.6 inches
# 359              NaN         Yes                 12.5       Yes   1.8 inches
#
#         Weight
# 0          NaN
# 1          NaN
# 2          NaN
# 3      <= 20 g
# 4          NaN
# ..         ...
# 355      75g +
# 356    <= 20 g
# 357        NaN
# 358    <= 20 g
# 359  20 - 35 g
#
# [360 rows x 16 columns]

# %%
train_df.tail()
# Out:
#           Brand  Current Price  Original Price  Discount Percentage  Rating  \
# 319        dizo         1799.0          4999.0            64.012803     4.2
# 239     amazfit         4499.0          5999.0            25.004167     4.1
# 429  fire-boltt         3499.0          9999.0            65.006501     3.7
# 131       apple        49666.0         50900.0             2.424361     4.5
# 43   crossbeats         2999.0          9999.0            70.007001     4.3
#
#      Number OF Ratings                                         Model Name  \
# 319            34953.0  Watch D 1.8 inch Dynamic display with 550nits ...
# 239              333.0  Bip 3 Pro with 1.69 inch Large Color Display B...
# 429                NaN                                          beast pro
# 131             1519.0  Watch Series7 (GPS + Cellular, 41mm)Blue Alumi...
# 43               674.0                                               Grit
#
#     Dial Shape Strap Color Strap Material Touchscreen  Battery Life (Days)  \
# 319  Rectangle       Black        Silicon         Yes                  8.0
# 239     Square       Beige        Silicon         Yes                  8.0
# 429     Square        Blue         Rubber         Yes                  8.0
# 131  Rectangle        Blue      Aluminium         Yes                 22.0
# 43         NaN         NaN            NaN         Yes                 12.5
#
#     Bluetooth Display Size     Weight
# 319       Yes   1.8 inches      75g +
# 239       Yes   1.7 inches    <= 20 g
# 429       Yes   0.1 inches        NaN
# 131       Yes   1.6 inches    <= 20 g
# 43        Yes   1.8 inches  20 - 35 g

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 360 entries, 265 to 43
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Brand                360 non-null    object
#  1   Current Price        350 non-null    float64
#  2   Original Price       298 non-null    float64
#  3   Discount Percentage  298 non-null    float64
#  4   Rating               354 non-null    float64
#  5   Number OF Ratings    316 non-null    float64
#  6   Model Name           331 non-null    object
#  7   Dial Shape           258 non-null    object
#  8   Strap Color          258 non-null    object
#  9   Strap Material       304 non-null    object
#  10  Touchscreen          330 non-null    object
#  11  Battery Life (Days)  337 non-null    float64
#  12  Bluetooth            355 non-null    object
#  13  Display Size         336 non-null    object
#  14  Weight               216 non-null    object
# dtypes: float64(6), object(9)
# memory usage: 45.0+ KB

# %%
df.describe(include="all")
# Out:
#              Brand  Current Price  Original Price  Discount Percentage  \
# count          450     440.000000      377.000000           377.000000
# unique          18            NaN             NaN                  NaN
# top     fire-boltt            NaN             NaN                  NaN
# freq            60            NaN             NaN                  NaN
# mean           NaN   12747.554545    14598.204244            48.236894
# std            NaN   17760.666099    15450.028869            24.109830
# min            NaN    1199.000000     1669.000000           -79.688436
# 25%            NaN    2180.750000     5999.000000            33.337037
# 50%            NaN    3999.000000     7999.000000            54.550414
# 75%            NaN   17121.750000    17999.000000            66.677780
# max            NaN  139990.000000    96390.000000            91.004550
#
#             Rating  Number OF Ratings Model Name Dial Shape Strap Color  \
# count   444.000000         391.000000        415        327         327
# unique         NaN                NaN        389          6          30
# top            NaN                NaN  beast pro     Circle       Black
# freq           NaN                NaN          5        131         133
# mean      4.031306       11594.726343        NaN        NaN         NaN
# std       0.550548       40423.889227        NaN        NaN         NaN
# min       1.000000           1.000000        NaN        NaN         NaN
# 25%       3.900000          68.500000        NaN        NaN         NaN
# 50%       4.100000         996.000000        NaN        NaN         NaN
# 75%       4.300000        6022.000000        NaN        NaN         NaN
# max       5.000000      619130.000000        NaN        NaN         NaN
#
#        Strap Material Touchscreen  Battery Life (Days) Bluetooth Display Size  \
# count             381         413           418.000000       444          420
# unique             15           2                  NaN         2           40
# top           Silicon         Yes                  NaN       Yes   1.7 inches
# freq              248         389                  NaN       440           68
# mean              NaN         NaN            14.077392       NaN          NaN
# std               NaN         NaN             7.718503       NaN          NaN
# min               NaN         NaN             0.750000       NaN          NaN
# 25%               NaN         NaN             8.000000       NaN          NaN
# 50%               NaN         NaN            17.500000       NaN          NaN
# 75%               NaN         NaN            22.000000       NaN          NaN
# max               NaN         NaN            22.000000       NaN          NaN
#
#            Weight
# count         264
# unique          5
# top     20 - 35 g
# freq           80
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN

# %%
df.describe()
# Out:
#        Current Price  Original Price  Discount Percentage      Rating  \
# count     440.000000      377.000000           377.000000  444.000000
# mean    12747.554545    14598.204244            48.236894    4.031306
# std     17760.666099    15450.028869            24.109830    0.550548
# min      1199.000000     1669.000000           -79.688436    1.000000
# 25%      2180.750000     5999.000000            33.337037    3.900000
# 50%      3999.000000     7999.000000            54.550414    4.100000
# 75%     17121.750000    17999.000000            66.677780    4.300000
# max    139990.000000    96390.000000            91.004550    5.000000
#
#        Number OF Ratings  Battery Life (Days)
# count         391.000000           418.000000
# mean        11594.726343            14.077392
# std         40423.889227             7.718503
# min             1.000000             0.750000
# 25%            68.500000             8.000000
# 50%           996.000000            17.500000
# 75%          6022.000000            22.000000
# max        619130.000000            22.000000

# %%
#cehck null values

train_df.isna().sum()
# Out:
# Brand                    0
# Current Price           10
# Original Price          62
# Discount Percentage     62
# Rating                   6
# Number OF Ratings       44
# Model Name              29
# Dial Shape             102
# Strap Color            102
# Strap Material          56
# Touchscreen             30
# Battery Life (Days)     23
# Bluetooth                5
# Display Size            24
# Weight                 144
# dtype: int64

# %%
num_cols = train_df.select_dtypes(include=['int64', 'float64']).columns
cat_cols = train_df.select_dtypes(include=['object']).columns

# %%
train_df[num_cols].describe()
# Out:
#        Current Price  Original Price  Discount Percentage      Rating  \
# count     350.000000      298.000000           298.000000  354.000000
# mean    12841.197143    14389.966443            49.226918    4.040678
# std     18099.038235    15025.991605            23.335617    0.541099
# min      1199.000000     1868.000000           -20.420179    1.000000
# 25%      2126.000000     5999.000000            33.510036    3.900000
# 50%      3999.000000     7999.000000            55.013753    4.100000
# 75%     16999.000000    16999.000000            66.677780    4.300000
# max    139990.000000    96390.000000            91.004550    5.000000
#
#        Number OF Ratings  Battery Life (Days)
# count         316.000000           337.000000
# mean        11907.240506            13.882344
# std         42603.893552             7.760790
# min             1.000000             0.750000
# 25%            80.250000             8.000000
# 50%          1343.500000            17.500000
# 75%          6825.000000            22.000000
# max        619130.000000            22.000000

# %%
train_df[cat_cols].describe()
# Out:
#              Brand Model Name Dial Shape Strap Color Strap Material  \
# count          360        331        258         258            304
# unique          18        309          5          27             15
# top     fire-boltt  beast pro     Circle       Black        Silicon
# freq            53          5        107         103            195
#
#        Touchscreen Bluetooth Display Size     Weight
# count          330       355          336        216
# unique           2         2           34          5
# top            Yes       Yes   1.7 inches  20 - 35 g
# freq           311       352           53         66

# %%
train_df[num_cols].corr()
# Out:
#                      Current Price  Original Price  Discount Percentage  \
# Current Price             1.000000        0.968181            -0.654405
# Original Price            0.968181        1.000000            -0.530270
# Discount Percentage      -0.654405       -0.530270             1.000000
# Rating                    0.403723        0.342103            -0.226286
# Number OF Ratings        -0.135607       -0.130622             0.195189
# Battery Life (Days)       0.063607       -0.112833            -0.015641
#
#                        Rating  Number OF Ratings  Battery Life (Days)
# Current Price        0.403723          -0.135607             0.063607
# Original Price       0.342103          -0.130622            -0.112833
# Discount Percentage -0.226286           0.195189            -0.015641
# Rating               1.000000           0.047546            -0.060746
# Number OF Ratings    0.047546           1.000000             0.056709
# Battery Life (Days) -0.060746           0.056709             1.000000

# %%
profile = pp.ProfileReport(train_df, title="EDA Report", explorative=True)
profile
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/15 [00:00<?, ?it/s]
# 100%|██████████| 15/15 [00:00<00:00, 92.01it/s][A
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;meta charset=utf-8&gt;&lt;meta content=&quot;width=device-width,initial-scale=1,shrink-to-fit=no&quot; name=viewport&gt;&lt;meta content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot; name=description&gt;&lt;meta content=&quot;YData and the open source community.&quot; name=author&gt;&lt;meta content=&quot;YData Profiling vv4.18.1&quot; name=generator&gt;&lt;meta content=https://github.com/ydataai/ydata-profiling name=url&gt;&lt;meta content=&quot;2026-03-29 08:16:42.235633&quot; name=date&gt;&lt;title&gt;EDA Report&lt;/title&gt;&lt;style&gt;@charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
#  */:root,[data-bs-theme=light]{--bs-blue:#0d6efd;--bs-indigo:#6610f2;--bs-purple:#6f42c1;--bs-pink:#d63384;--bs-red:#dc3545;--bs-orange:#fd7e14;--bs-yellow:#ffc107;--bs-green:#198754;--bs-teal:#20c997;--bs-cyan:#0dcaf0;--bs-black:#000;--bs-white:#fff;--bs-gray:#6c757d;--bs-gray-dark:#343a40;--bs-gray-100:#f8f9fa;--bs-gray-200:#e9ecef;--bs-gray-300:#dee2e6;--bs-gray-400:#ced4da;--bs-gray-500:#adb5bd;--bs-gray-600:#6c757d;--bs-gray-700:#495057;--bs-gray-800:#343a40;--bs-gray-900:#212529;--bs-primary:#0d6efd;--bs-secondary:#6c757d;--bs-success:#198754;--bs-info:#0dcaf0;--bs-warning:#ffc107;--bs-danger:#dc3545;--bs-light:#f8f9fa;--bs-dark:#212529;--bs-primary-rgb:13,110,253;--bs-secondary-rgb:108,117,125;--bs-success-rgb:25,135,84;--bs-info-rgb:13,202,240;--bs-warning-rgb:255,193,7;--bs-danger-rgb:220,53,69;--bs-light-rgb:248,249,250;--bs-dark-rgb:33,37,41;--bs-primary-text-emphasis:#052c65;--bs-secondary-text-emphasis:#2b2f32;--bs-success-text-emphasis:#0a3622;--bs-info-text-emphasis:#055160;--bs-warning-text-emphasis:#664d03;--bs-danger-text-emphasis:#58151c;--bs-light-text-emphasis:#495057;--bs-dark-text-emphasis:#495057;--bs-primary-bg-subtle:#cfe2ff;--bs-secondary-bg-subtle:#e2e3e5;--bs-success-bg-subtle:#d1e7dd;--bs-info-bg-subtle:#cff4fc;--bs-warning-bg-subtle:#fff3cd;--bs-danger-bg-subtle:#f8d7da;--bs-light-bg-subtle:#fcfcfd;--bs-dark-bg-subtle:#ced4da;--bs-primary-border-subtle:#9ec5fe;--bs-secondary-border-subtle:#c4c8cb;--bs-success-border-subtle:#a3cfbb;--bs-info-border-subtle:#9eeaf9;--bs-warning-border-subtle:#ffe69c;--bs-danger-border-subtle:#f1aeb5;--bs-light-border-subtle:#e9ecef;--bs-dark-border-subtle:#adb5bd;--bs-white-rgb:255,255,255;--bs-black-rgb:0,0,0;--bs-font-sans-serif:system-ui,-apple-system,&quot;Segoe UI&quot;,Roboto,&quot;Helvetica Neue&quot;,&quot;Noto Sans&quot;,&quot;Liberation Sans&quot;,Arial,sans-serif,&quot;Apple Color Emoji&quot;,&quot;Segoe UI Emoji&quot;,&quot;Segoe UI Symbol&quot;,&quot;Noto Color Emoji&quot;;--bs-font-monospace:SFMono-Regular,Menlo,Monaco,Consolas,&quot;Liberation Mono&quot;,&quot;Courier New&quot;,monospace;--bs-gradient:linear-gradient(180deg, rgba(255, 255, 255, 0.15), rgba(255, 255, 255, 0));--bs-body-font-family:var(--bs-font-sans-serif);--bs-body-font-size:1rem;--bs-body-font-weight:400;--bs-body-line-height:1.5;--bs-body-color:#212529;--bs-body-color-rgb:33,37,41;--bs-body-bg:#fff;--bs-body-bg-rgb:255,255,255;--bs-emphasis-color:#000;--bs-emphasis-color-rgb:0,0,0;--bs-secondary-color:rgba(33, 37, 41, 0.75);--bs-secondary-color-rgb:33,37,41;--bs-secondary-bg:#e9ecef;--bs-secondary-bg-rgb:233,236,239;--bs-tertiary-color:rgba(33, 37, 41, 0.5);--bs-tertiary-color-rgb:33,37,41;--bs-tertiary-bg:#f8f9fa;--bs-tertiary-bg-rgb:248,249,250;--bs-heading-color:inherit;--bs-link-color:#0d6efd;--bs-link-color-rgb:13,110,253;--bs-link-decoration:underline;--bs-link-hover-color:#0a58ca;--bs-link-hover-color-rgb:10,88,202;--bs-code-color:#d63384;--bs-highlight-color:#212529;--bs-highlight-bg:#fff3cd;--bs-border-width:1px;--bs-border-style:solid;--bs-border-color:#dee2e6;--bs-border-color-translucent:rgba(0, 0, 0, 0.175);--bs-border-radius:0.375rem;--bs-border-radius-sm:0.25rem;--bs-border-radius-lg:0.5rem;--bs-border-radius-xl:1rem;--bs-border-radius-xxl:2rem;--bs-border-radius-2xl:var(--bs-border-radius-xxl);--bs-border-radius-pill:50rem;--bs-box-shadow:0 0.5rem 1rem rgba(0, 0, 0, 0.15);--bs-box-shadow-sm:0 0.125rem 0.25rem rgba(0, 0, 0, 0.075);--bs-box-shadow-lg:0 1rem 3rem rgba(0, 0, 0, 0.175);--bs-box-shadow-inset:inset 0 1px 2px rgba(0, 0, 0, 0.075);--bs-focus-ring-width:0.25rem;--bs-focus-ring-opacity:0.25;--bs-focus-ring-color:rgba(13, 110, 253, 0.25);--bs-form-valid-color:#198754;--bs-form-valid-border-color:#198754;--bs-form-invalid-color:#dc3545;--bs-form-invalid-border-color:#dc3545}[data-bs-theme=dark]{color-scheme:dark;--bs-body-color:#dee2e6;--bs-body-color-rgb:222,226,230;--bs-body-bg:#212529;--bs-body-bg-rgb:33,37,41;--bs-emphasis-color:#fff;--bs-emphasis-color-rgb:2 ...

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(14, 10))
axes = axes.flatten()

for i, col in enumerate(num_cols):
    sns.histplot(df[col], ax=axes[i], kde=True)
    axes[i].set_title(col)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_28200\3137837004.py:9: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
